# %% [markdown]
# # Titanic - Data Exploration #4

# %% [markdown]
# ## Load libraries

# %%
import os
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

import myUtilities as myUtils

# %% [markdown]
# ## Load dataset

# %%
train_set, test_set = myUtils.load_titanic_datasets()
all_set = pd.concat([train_set, test_set], sort=False)

# %% [markdown]
# ## Explore dataset for outliers

# %%
train_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
train_set["Age"].hist(bins=50, figsize=(15, 7))
plt.show()

# %%
# Explore Age > 70

train_set.loc[train_set["Age"] > 69]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>PassengerId</th>
#       <th>Survived</th>
#       <th>Pclass</th>
#       <th>Name</th>
#       <th>Sex</th>
#       <th>Age</th>
#       <th>SibSp</th>
#       <th>Parch</th>
#       <th>Ticket</th>
#       <th>Fare</th>
#       <th>Cabin</th>
#       <th>Embarked</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>96</th>
#       <td>97</td>
#       <td>0</td>
#       <td>1</td>
#       <td>Goldschmidt, Mr. George B</td>
#       <td>male</td>
#       <td>71.0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>PC 17754</td>
#       <td>34.6542</td>
#       <td>A5</td>
#       <td>C</td>
# ...

# %%
# Explore the passengers travelling with Passengerid = 746 (Crosby).

all_set.loc[all_set["Ticket"].str.contains('WE/P 5735')]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>PassengerId</th>
#       <th>Survived</th>
#       <th>Pclass</th>
#       <th>Name</th>
#       <th>Sex</th>
#       <th>Age</th>
#       <th>SibSp</th>
#       <th>Parch</th>
#       <th>Ticket</th>
#       <th>Fare</th>
#       <th>Cabin</th>
#       <th>Embarked</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>540</th>
#       <td>541</td>
#       <td>1.0</td>
#       <td>1</td>
#       <td>Crosby, Miss. Harriet R</td>
#       <td>female</td>
#       <td>36.0</td>
#       <td>0</td>
#       <td>2</td>
#       <td>WE/P 5735</td>
#       <td>71.0</td>
#       <td>B22</td>
#       <td>S</td>
# ...

# %%
all_set.loc[all_set["Cabin"].str.contains('B22', na=False)]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>PassengerId</th>
#       <th>Survived</th>
#       <th>Pclass</th>
#       <th>Name</th>
#       <th>Sex</th>
#       <th>Age</th>
#       <th>SibSp</th>
#       <th>Parch</th>
#       <th>Ticket</th>
#       <th>Fare</th>
#       <th>Cabin</th>
#       <th>Embarked</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>540</th>
#       <td>541</td>
#       <td>1.0</td>
#       <td>1</td>
#       <td>Crosby, Miss. Harriet R</td>
#       <td>female</td>
#       <td>36.0</td>
#       <td>0</td>
#       <td>2</td>
#       <td>WE/P 5735</td>
#       <td>71.0</td>
#       <td>B22</td>
#       <td>S</td>
# ...

# %%
all_set.loc[all_set["Name"].str.contains('Crosby', na=False)]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>PassengerId</th>
#       <th>Survived</th>
#       <th>Pclass</th>
#       <th>Name</th>
#       <th>Sex</th>
#       <th>Age</th>
#       <th>SibSp</th>
#       <th>Parch</th>
#       <th>Ticket</th>
#       <th>Fare</th>
#       <th>Cabin</th>
#       <th>Embarked</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>540</th>
#       <td>541</td>
#       <td>1.0</td>
#       <td>1</td>
#       <td>Crosby, Miss. Harriet R</td>
#       <td>female</td>
#       <td>36.0</td>
#       <td>0</td>
#       <td>2</td>
#       <td>WE/P 5735</td>
#       <td>71.00</td>
#       <td>B22</td>
#       <td>S</td>
# ...

# %%
# PassengerId 631 is trvelling alone.
all_set.loc[all_set["Ticket"].str.contains('27042')]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>PassengerId</th>
#       <th>Survived</th>
#       <th>Pclass</th>
#       <th>Name</th>
#       <th>Sex</th>
#       <th>Age</th>
#       <th>SibSp</th>
#       <th>Parch</th>
#       <th>Ticket</th>
#       <th>Fare</th>
#       <th>Cabin</th>
#       <th>Embarked</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>630</th>
#       <td>631</td>
#       <td>1.0</td>
#       <td>1</td>
#       <td>Barkworth, Mr. Algernon Henry Wilson</td>
#       <td>male</td>
#       <td>80.0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>27042</td>
#       <td>30.0</td>
#       <td>A23</td>
# ...

# %%
all_set.loc[all_set["Cabin"].str.contains('A23', na=False)]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>PassengerId</th>
#       <th>Survived</th>
#       <th>Pclass</th>
#       <th>Name</th>
#       <th>Sex</th>
#       <th>Age</th>
#       <th>SibSp</th>
#       <th>Parch</th>
#       <th>Ticket</th>
#       <th>Fare</th>
#       <th>Cabin</th>
#       <th>Embarked</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>630</th>
#       <td>631</td>
#       <td>1.0</td>
#       <td>1</td>
#       <td>Barkworth, Mr. Algernon Henry Wilson</td>
#       <td>male</td>
#       <td>80.0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>27042</td>
#       <td>30.0</td>
#       <td>A23</td>
# ...

# %%
all_set.loc[all_set["Name"].str.contains('Barkworth', na=False)]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>PassengerId</th>
#       <th>Survived</th>
#       <th>Pclass</th>
#       <th>Name</th>
#       <th>Sex</th>
#       <th>Age</th>
#       <th>SibSp</th>
#       <th>Parch</th>
#       <th>Ticket</th>
#       <th>Fare</th>
#       <th>Cabin</th>
#       <th>Embarked</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>630</th>
#       <td>631</td>
#       <td>1.0</td>
#       <td>1</td>
#       <td>Barkworth, Mr. Algernon Henry Wilson</td>
#       <td>male</td>
#       <td>80.0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>27042</td>
#       <td>30.0</td>
#       <td>A23</td>
# ...

# %%
# Explore Age < 10 without any Parch relationship.

train_set.loc[(train_set["Age"] < 15) & (train_set["Parch"] < 1)]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>PassengerId</th>
#       <th>Survived</th>
#       <th>Pclass</th>
#       <th>Name</th>
#       <th>Sex</th>
#       <th>Age</th>
#       <th>SibSp</th>
#       <th>Parch</th>
#       <th>Ticket</th>
#       <th>Fare</th>
#       <th>Cabin</th>
#       <th>Embarked</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>9</th>
#       <td>10</td>
#       <td>1</td>
#       <td>2</td>
#       <td>Nasser, Mrs. Nicholas (Adele Achem)</td>
#       <td>female</td>
#       <td>14.0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>237736</td>
#       <td>30.0708</td>
#       <td>NaN</td>
# ...

# %%
# Explore PassengerId = 10. In 1900s, women married in their teens or early 20s.
all_set.loc[(all_set['Name'].str.contains('Nasser', na=False))]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>PassengerId</th>
#       <th>Survived</th>
#       <th>Pclass</th>
#       <th>Name</th>
#       <th>Sex</th>
#       <th>Age</th>
#       <th>SibSp</th>
#       <th>Parch</th>
#       <th>Ticket</th>
#       <th>Fare</th>
#       <th>Cabin</th>
#       <th>Embarked</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>9</th>
#       <td>10</td>
#       <td>1.0</td>
#       <td>2</td>
#       <td>Nasser, Mrs. Nicholas (Adele Achem)</td>
#       <td>female</td>
#       <td>14.0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>237736</td>
#       <td>30.0708</td>
#       <td>NaN</td>
# ...

# %%
# Explore PassengerId = 778 without SibSp or Parch.
all_set.loc[(all_set['Name'].str.contains('Emanuel', na=False))]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>PassengerId</th>
#       <th>Survived</th>
#       <th>Pclass</th>
#       <th>Name</th>
#       <th>Sex</th>
#       <th>Age</th>
#       <th>SibSp</th>
#       <th>Parch</th>
#       <th>Ticket</th>
#       <th>Fare</th>
#       <th>Cabin</th>
#       <th>Embarked</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>777</th>
#       <td>778</td>
#       <td>1.0</td>
#       <td>3</td>
#       <td>Emanuel, Miss. Virginia Ethel</td>
#       <td>female</td>
#       <td>5.00</td>
#       <td>0</td>
#       <td>0</td>
#       <td>364516</td>
#       <td>12.475</td>
#       <td>NaN</td>
# ...

# %%
# PassengerId = 778 appears to be travelling with PassengerId = 80.
all_set.loc[(all_set['Ticket'].str.contains('364516', na=False))]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>PassengerId</th>
#       <th>Survived</th>
#       <th>Pclass</th>
#       <th>Name</th>
#       <th>Sex</th>
#       <th>Age</th>
#       <th>SibSp</th>
#       <th>Parch</th>
#       <th>Ticket</th>
#       <th>Fare</th>
#       <th>Cabin</th>
#       <th>Embarked</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>79</th>
#       <td>80</td>
#       <td>1.0</td>
#       <td>3</td>
#       <td>Dowdell, Miss. Elizabeth</td>
#       <td>female</td>
#       <td>30.0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>364516</td>
#       <td>12.475</td>
#       <td>NaN</td>
#       <td>S</td>
# ...

# %%
# Explore PassengerId=732 also without SibSp and Parch.
all_set.loc[(all_set['Name'].str.contains('Hassan', na=False))]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>PassengerId</th>
#       <th>Survived</th>
#       <th>Pclass</th>
#       <th>Name</th>
#       <th>Sex</th>
#       <th>Age</th>
#       <th>SibSp</th>
#       <th>Parch</th>
#       <th>Ticket</th>
#       <th>Fare</th>
#       <th>Cabin</th>
#       <th>Embarked</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>731</th>
#       <td>732</td>
#       <td>0.0</td>
#       <td>3</td>
#       <td>Hassan, Mr. Houssein G N</td>
#       <td>male</td>
#       <td>11.0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>2699</td>
#       <td>18.7875</td>
#       <td>NaN</td>
#       <td>C</td>
# ...

# %%
# PassengerId = 732 appears to be travelling with PassengerId = 208.
all_set.loc[(all_set['Ticket'].str.contains('2699', na=False))]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>PassengerId</th>
#       <th>Survived</th>
#       <th>Pclass</th>
#       <th>Name</th>
#       <th>Sex</th>
#       <th>Age</th>
#       <th>SibSp</th>
#       <th>Parch</th>
#       <th>Ticket</th>
#       <th>Fare</th>
#       <th>Cabin</th>
#       <th>Embarked</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>207</th>
#       <td>208</td>
#       <td>1.0</td>
#       <td>3</td>
#       <td>Albimona, Mr. Nassef Cassem</td>
#       <td>male</td>
#       <td>26.0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>2699</td>
#       <td>18.7875</td>
#       <td>NaN</td>
#       <td>C</td>
# ...

# %%
# Explore PassengerId=15 also without SibSp and Parch.
all_set.loc[(all_set['Name'].str.contains('Vestrom', na=False))]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>PassengerId</th>
#       <th>Survived</th>
#       <th>Pclass</th>
#       <th>Name</th>
#       <th>Sex</th>
#       <th>Age</th>
#       <th>SibSp</th>
#       <th>Parch</th>
#       <th>Ticket</th>
#       <th>Fare</th>
#       <th>Cabin</th>
#       <th>Embarked</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>14</th>
#       <td>15</td>
#       <td>0.0</td>
#       <td>3</td>
#       <td>Vestrom, Miss. Hulda Amanda Adolfina</td>
#       <td>female</td>
#       <td>14.0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>350406</td>
#       <td>7.8542</td>
#       <td>NaN</td>
# ...

# %%
# PassengerId=15 was travelling  with others () according to the Titanic Encyclopedia. But there is no way to show this in the data, 
all_set.loc[(all_set['Ticket'].str.contains('3504', na=False))]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>PassengerId</th>
#       <th>Survived</th>
#       <th>Pclass</th>
#       <th>Name</th>
#       <th>Sex</th>
#       <th>Age</th>
#       <th>SibSp</th>
#       <th>Parch</th>
#       <th>Ticket</th>
#       <th>Fare</th>
#       <th>Cabin</th>
#       <th>Embarked</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>14</th>
#       <td>15</td>
#       <td>0.0</td>
#       <td>3</td>
#       <td>Vestrom, Miss. Hulda Amanda Adolfina</td>
#       <td>female</td>
#       <td>14.0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>350406</td>
#       <td>7.8542</td>
#       <td>NaN</td>
# ...

# %%
train_set["Fare"].hist(bins=50, figsize=(15, 7))

# %%
# Explore Fare > 500
all_set.loc[all_set["Fare"] > 500]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>PassengerId</th>
#       <th>Survived</th>
#       <th>Pclass</th>
#       <th>Name</th>
#       <th>Sex</th>
#       <th>Age</th>
#       <th>SibSp</th>
#       <th>Parch</th>
#       <th>Ticket</th>
#       <th>Fare</th>
#       <th>Cabin</th>
#       <th>Embarked</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>258</th>
#       <td>259</td>
#       <td>1.0</td>
#       <td>1</td>
#       <td>Ward, Miss. Anna</td>
#       <td>female</td>
#       <td>35.0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>PC 17755</td>
#       <td>512.3292</td>
#       <td>NaN</td>
#       <td>C</td>
# ...

# %%
all_set.loc[(all_set["Fare"] < 400) & (all_set["Fare"] > 200)]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>PassengerId</th>
#       <th>Survived</th>
#       <th>Pclass</th>
#       <th>Name</th>
#       <th>Sex</th>
#       <th>Age</th>
#       <th>SibSp</th>
#       <th>Parch</th>
#       <th>Ticket</th>
#       <th>Fare</th>
#       <th>Cabin</th>
#       <th>Embarked</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>27</th>
#       <td>28</td>
#       <td>0.0</td>
#       <td>1</td>
#       <td>Fortune, Mr. Charles Alexander</td>
#       <td>male</td>
#       <td>19.0</td>
#       <td>3</td>
#       <td>2</td>
#       <td>19950</td>
#       <td>263.0000</td>
#       <td>C23 C25 C27</td>
# ...
